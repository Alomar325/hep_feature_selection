# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#https://www.kaggle.com/c/higgs-boson/data
#https://higgsml.ijclab.in2p3.fr
#https://higgsml.ijclab.in2p3.fr
#https://opendata.cern.ch/record/328

# %% [markdown]
# # Leer datos

# %%
df = pd.read_csv("/Users/rpezoa/Downloads/atlas-higgs-challenge-2014-v2.csv")

# %%
df.head()
# Out:
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000       138.470                       51.655        97.827    27.980
# 1   100001       160.937                       68.768       103.235    48.146
# 2   100002      -999.000                      162.172       125.953    35.635
# 3   100003       143.905                       81.417        80.943     0.414
# 4   100004       175.864                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  0.91           124.711                2.666
# 1               -999.00          -999.000             -999.000
# 2               -999.00          -999.000             -999.000
# 3               -999.00          -999.000             -999.000
# 4               -999.00          -999.000             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_leading_eta  \
# 0               3.064      41.928  ...                2.150
# 1               3.473       2.078  ...                0.725
# 2               3.148       9.336  ...                2.053
# 3               3.310       0.414  ...             -999.000
# 4               3.891      16.405  ...             -999.000
#
#    PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0                0.444                 46.062                    1.24
# 1                1.158               -999.000                 -999.00
# 2               -2.028               -999.000                 -999.00
# 3             -999.000               -999.000                 -999.00
# 4             -999.000               -999.000                 -999.00
#
#    PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  Label  KaggleSet  \
# 0                  -2.475         113.497  0.000814      s          t
# 1                -999.000          46.226  0.681042      b          t
# 2                -999.000          44.251  0.715742      b          t
# 3                -999.000          -0.000  1.660654      b          t
# 4                -999.000           0.000  1.904263      b          t
#
#    KaggleWeight
# 0      0.002653
# 1      2.233584
# 2      2.347389
# 3      5.446378
# 4      6.245333
#
# [5 rows x 35 columns]

# %%
df.columns
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt',
#        'Weight', 'Label', 'KaggleSet', 'KaggleWeight'],
#       dtype='object')

# %%
df.dtypes
# Out:
# EventId                          int64
# DER_mass_MMC                   float64
# DER_mass_transverse_met_lep    float64
# DER_mass_vis                   float64
# DER_pt_h                       float64
# DER_deltaeta_jet_jet           float64
# DER_mass_jet_jet               float64
# DER_prodeta_jet_jet            float64
# DER_deltar_tau_lep             float64
# DER_pt_tot                     float64
# DER_sum_pt                     float64
# DER_pt_ratio_lep_tau           float64
# DER_met_phi_centrality         float64
# DER_lep_eta_centrality         float64
# PRI_tau_pt                     float64
# PRI_tau_eta                    float64
# PRI_tau_phi                    float64
# PRI_lep_pt                     float64
# PRI_lep_eta                    float64
# PRI_lep_phi                    float64
# PRI_met                        float64
# PRI_met_phi                    float64
# PRI_met_sumet                  float64
# PRI_jet_num                      int64
# PRI_jet_leading_pt             float64
# PRI_jet_leading_eta            float64
# PRI_jet_leading_phi            float64
# PRI_jet_subleading_pt          float64
# PRI_jet_subleading_eta         float64
# PRI_jet_subleading_phi         float64
# PRI_jet_all_pt                 float64
# Weight                         float64
# Label                           object
# KaggleSet                       object
# KaggleWeight                   float64
# dtype: object

# %%
df.describe()
# Out:
#              EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  818238.000000  818238.000000                818238.000000
# mean   509118.500000     -48.819019                    49.252714
# std    236205.109119     406.118397                    35.378609
# min    100000.000000    -999.000000                     0.000000
# 25%    304559.250000      78.166000                    19.304000
# 50%    509118.500000     105.061000                    46.484000
# 75%    713677.750000     130.730000                    73.620000
# max    918237.000000    1949.261000                   968.669000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  818238.000000  818238.000000         818238.000000     818238.000000
# mean       81.140561      57.849524           -707.740880       -600.191191
# std        40.582708      63.411938            454.793899        658.724040
# min         6.329000       0.000000           -999.000000       -999.000000
# 25%        59.414000      14.164250           -999.000000       -999.000000
# 50%        73.744000      38.470000           -999.000000       -999.000000
# 75%        92.188000      79.226750              0.499000         84.031750
# max      1349.351000    2834.999000              8.724000       4974.979000
#
#        DER_prodeta_jet_jet  DER_deltar_tau_lep     DER_pt_tot  ...  \
# count        818238.000000       818238.000000  818238.000000  ...
# mean           -708.681306            2.373871      18.969617  ...
# std             453.328599            0.780875      21.918491  ...
# min            -999.000000            0.208000       0.000000  ...
# 25%            -999.000000            1.814000       2.839000  ...
# 50%            -999.000000            2.492000      12.383000  ...
# 75%              -4.548000            2.962000      27.634000  ...
# max              17.650000            5.751000    2834.999000  ...
#
#          PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  818238.000000       818238.000000        818238.000000
# mean        0.979923         -348.757840          -399.693294
# std         0.978793          533.097006           489.428560
# min         0.000000         -999.000000          -999.000000
# 25%         0.000000         -999.000000          -999.000000
# 50%         1.000000           38.965000            -1.865000
# 75%         2.000000           75.470750             0.432000
# max         3.000000         1163.439000             4.500000
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# count        818238.000000          818238.000000           818238.000000
# mean           -399.703858            -691.626111             -708.442206
# std             489.420013             480.274744              453.699150
# min            -999.000000            -999.000000             -999.000000
# 25%            -999.000000            -999.000000             -999.000000
# 50%              -2.105000            -999.000000             -999.000000
# 75%               0.489000              33.800000               -2.436000
# max               3.142000             817.801000                4.500000
#
#        PRI_jet_subleading_phi  PRI_jet_all_pt         Weight   KaggleWeight
# count           818238.000000   818238.000000  818238.000000  818238.000000
# mean              -708.443312       73.205594       0.503144       2.012577
# std                453.697158       98.331754       0.572200       5.439641
# min               -999.000000       -0.000000       0.000461       0.000839
# 25%               -999.000000        0.000000       0.005721       0.010415
# 50%               -999.000000       40.506000       0.357223       0.806562
# 75%                 -2.265000      110.387000       0.733462       2.360271
# max                  3.142000     1860.175000       2.386316     106.908407
#
# [8 rows x 33 columns]

# %%
describe_num_df = df.describe(include=['int64','float64'])
describe_num_df.reset_index(inplace=True)

# %%
describe_num_df
# Out:
#    index        EventId   DER_mass_MMC  DER_mass_transverse_met_lep  \
# 0  count  818238.000000  818238.000000                818238.000000
# 1   mean  509118.500000     -48.819019                    49.252714
# 2    std  236205.109119     406.118397                    35.378609
# 3    min  100000.000000    -999.000000                     0.000000
# 4    25%  304559.250000      78.166000                    19.304000
# 5    50%  509118.500000     105.061000                    46.484000
# 6    75%  713677.750000     130.730000                    73.620000
# 7    max  918237.000000    1949.261000                   968.669000
#
#     DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# 0  818238.000000  818238.000000         818238.000000     818238.000000
# 1      81.140561      57.849524           -707.740880       -600.191191
# 2      40.582708      63.411938            454.793899        658.724040
# 3       6.329000       0.000000           -999.000000       -999.000000
# 4      59.414000      14.164250           -999.000000       -999.000000
# 5      73.744000      38.470000           -999.000000       -999.000000
# 6      92.188000      79.226750              0.499000         84.031750
# 7    1349.351000    2834.999000              8.724000       4974.979000
#
#    DER_prodeta_jet_jet  DER_deltar_tau_lep  ...    PRI_jet_num  \
# 0        818238.000000       818238.000000  ...  818238.000000
# 1          -708.681306            2.373871  ...       0.979923
# 2           453.328599            0.780875  ...       0.978793
# 3          -999.000000            0.208000  ...       0.000000
# 4          -999.000000            1.814000  ...       0.000000
# 5          -999.000000            2.492000  ...       1.000000
# 6            -4.548000            2.962000  ...       2.000000
# 7            17.650000            5.751000  ...       3.000000
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0       818238.000000        818238.000000        818238.000000
# 1         -348.757840          -399.693294          -399.703858
# 2          533.097006           489.428560           489.420013
# 3         -999.000000          -999.000000          -999.000000
# 4         -999.000000          -999.000000          -999.000000
# 5           38.965000            -1.865000            -2.105000
# 6           75.470750             0.432000             0.489000
# 7         1163.439000             4.500000             3.142000
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0          818238.000000           818238.000000           818238.000000
# 1            -691.626111             -708.442206             -708.443312
# 2             480.274744              453.699150              453.697158
# 3            -999.000000             -999.000000             -999.000000
# 4            -999.000000             -999.000000             -999.000000
# 5            -999.000000             -999.000000             -999.000000
# 6              33.800000               -2.436000               -2.265000
# 7             817.801000                4.500000                3.142000
#
#    PRI_jet_all_pt         Weight   KaggleWeight
# 0   818238.000000  818238.000000  818238.000000
# 1       73.205594       0.503144       2.012577
# 2       98.331754       0.572200       5.439641
# 3       -0.000000       0.000461       0.000839
# 4        0.000000       0.005721       0.010415
# 5       40.506000       0.357223       0.806562
# 6      110.387000       0.733462       2.360271
# 7     1860.175000       2.386316     106.908407
#
# [8 rows x 34 columns]

# %%
describe_num_df2 = describe_num_df.drop(labels=0, axis=0)

# %%
num_col = df._get_numeric_data().columns

# %%
num_col
# Out:
# Index(['EventId', 'DER_mass_MMC', 'DER_mass_transverse_met_lep',
#        'DER_mass_vis', 'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt',
#        'Weight', 'KaggleWeight'],
#       dtype='object')

# %%
# To remove any variable from plot
describe_num_df2 = describe_num_df2[describe_num_df2['index'] != 'EventId']
for i in num_col:
    if (i in ['index'] or i in ['EventId']) :
        
        continue
    print(i)
    sns.factorplot(x='index', y=i, data=describe_num_df2)
    
    plt.show()
# Out:
# DER_mass_MMC
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_mass_transverse_met_lep
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_mass_vis
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_pt_h
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_deltaeta_jet_jet
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_mass_jet_jet
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_prodeta_jet_jet
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_deltar_tau_lep
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_pt_tot
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_sum_pt
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_pt_ratio_lep_tau
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_met_phi_centrality
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# DER_lep_eta_centrality
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_tau_pt
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_tau_eta
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_tau_phi
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_lep_pt
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_lep_eta
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_lep_phi
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_met
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_met_phi
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_met_sumet
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_num
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_leading_pt
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_leading_eta
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_leading_phi
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_subleading_pt
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_subleading_eta
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_subleading_phi
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# PRI_jet_all_pt
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# Weight
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# KaggleWeight
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
df["Label"].value_counts()
# Out:
# b    538678
# s    279560
# Name: Label, dtype: int64

# %% [markdown]
# ## Revisión de atributos faltantes (missing attributes)

# %%
def show_null(df):
    total = df.isnull().sum().sort_values(ascending=False)
    percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
    missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
    display(missing_data)
show_null(df)
# Out:
#                              Total  Percent
# EventId                          0      0.0
# PRI_jet_leading_phi              0      0.0
# PRI_met                          0      0.0
# PRI_met_phi                      0      0.0
# PRI_met_sumet                    0      0.0
# PRI_jet_num                      0      0.0
# PRI_jet_leading_pt               0      0.0
# PRI_jet_leading_eta              0      0.0
# PRI_jet_subleading_pt            0      0.0
# PRI_lep_eta                      0      0.0
# PRI_jet_subleading_eta           0      0.0
# PRI_jet_subleading_phi           0      0.0
# PRI_jet_all_pt                   0      0.0
# Weight                           0      0.0
# Label                            0      0.0
# KaggleSet                        0      0.0
# PRI_lep_phi                      0      0.0
# PRI_lep_pt                       0      0.0
# DER_mass_MMC                     0      0.0
# DER_deltar_tau_lep               0      0.0
# DER_mass_transverse_met_lep      0      0.0
# DER_mass_vis                     0      0.0
# DER_pt_h                         0      0.0
# DER_deltaeta_jet_jet             0      0.0
# DER_mass_jet_jet                 0      0.0
# DER_prodeta_jet_jet              0      0.0
# DER_pt_tot                       0      0.0
# PRI_tau_phi                      0      0.0
# DER_sum_pt                       0      0.0
# DER_pt_ratio_lep_tau             0      0.0
# DER_met_phi_centrality           0      0.0
# DER_lep_eta_centrality           0      0.0
# PRI_tau_pt                       0      0.0
# PRI_tau_eta                      0      0.0
# KaggleWeight                     0      0.0

# %%
## Correlación entre variables

# %%
corr_matrix = df.corr()
plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap='BrBG', annot = True, fmt=".2f", annot_kws={"size":7})
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':8}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ## Gráfico de puntos entre pares de variables

# %%
plt.figure(figsize=(7, 4))
plt.scatter(df["PRI_jet_all_pt"], df["PRI_tau_pt"],s=0.5, alpha=0.6,color="C0")
plt.grid(ls=":", color="k")
plt.xlabel("lepton_pt")
plt.ylabel("lepton_eta")
plt.show()

# %%
#pair plot (matrix scatterplot) of few columns
sns.set(style="ticks", color_codes=True)
sns.pairplot(df,vars = ['DER_mass_MMC',
       'PRI_tau_pt', 'DER_mass_vis'], hue="Label")
plt.show()
# Out:
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/seaborn/utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# /opt/anaconda3/envs/root_py/lib/python3.8/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
