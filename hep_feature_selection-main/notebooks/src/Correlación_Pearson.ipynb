# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado.csv")

# %%
corr_matrix = df.corr(method="pearson")
plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(corr_matrix, vmin=-1, vmax=1, cmap='BrBG', annot = True, fmt=".2f", annot_kws={"size":7})
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':8}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
corr_matrix
# Out:
#                              DER_mass_MMC  DER_mass_transverse_met_lep  \
# DER_mass_MMC                     1.000000                    -0.454565
# DER_mass_transverse_met_lep     -0.454565                     1.000000
# DER_mass_vis                     0.172250                     0.187320
# DER_pt_h                         0.197366                    -0.253299
# DER_deltaeta_jet_jet             0.161830                    -0.179828
# DER_mass_jet_jet                 0.160355                    -0.192933
# DER_prodeta_jet_jet              0.161689                    -0.179401
# DER_deltar_tau_lep               0.230467                     0.042715
# DER_pt_tot                       0.048663                     0.009326
# DER_sum_pt                       0.199939                    -0.146486
# DER_pt_ratio_lep_tau            -0.014223                     0.340963
# DER_met_phi_centrality           0.358729                    -0.418197
# DER_lep_eta_centrality           0.161790                    -0.179705
# PRI_tau_pt                       0.127415                    -0.136176
# PRI_tau_eta                      0.004587                    -0.005670
# PRI_tau_phi                     -0.006143                     0.000150
# PRI_lep_pt                       0.102582                     0.304080
# PRI_lep_eta                      0.007381                    -0.006909
# PRI_lep_phi                     -0.004642                     0.002538
# PRI_met                         -0.237121                     0.183764
# PRI_met_phi                      0.007564                    -0.018560
# PRI_met_sumet                    0.219977                    -0.165226
# PRI_jet_num                      0.219547                    -0.210067
# PRI_jet_leading_pt               0.246436                    -0.226202
# PRI_jet_leading_eta              0.243233                    -0.216544
# PRI_jet_leading_phi              0.243216                    -0.216529
# PRI_jet_subleading_pt            0.162034                    -0.180302
# PRI_jet_subleading_eta           0.161788                    -0.179674
# PRI_jet_subleading_phi           0.161785                    -0.179682
# PRI_jet_all_pt                   0.183876                    -0.209717
# Label                            0.237261                    -0.351159
#
#                              DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  \
# DER_mass_MMC                     0.172250  0.197366              0.161830
# DER_mass_transverse_met_lep      0.187320 -0.253299             -0.179828
# DER_mass_vis                     1.000000 -0.061082             -0.030928
# DER_pt_h                        -0.061082  1.000000              0.523925
# DER_deltaeta_jet_jet            -0.030928  0.523925              1.000000
# DER_mass_jet_jet                -0.038740  0.536391              0.946692
# DER_prodeta_jet_jet             -0.030808  0.523899              0.999981
# DER_deltar_tau_lep               0.577503 -0.544633             -0.301857
# DER_pt_tot                      -0.001245  0.302904              0.284992
# DER_sum_pt                       0.090625  0.833710              0.669586
# DER_pt_ratio_lep_tau             0.100225  0.087215              0.032426
# DER_met_phi_centrality          -0.093310  0.540353              0.373591
# DER_lep_eta_centrality          -0.030901  0.523979              0.999998
# PRI_tau_pt                       0.286945  0.410942              0.189456
# PRI_tau_eta                     -0.001179  0.005686              0.008666
# PRI_tau_phi                     -0.005519  0.005706              0.004398
# PRI_lep_pt                       0.405197  0.362919              0.161729
# PRI_lep_eta                      0.009118  0.012058              0.013308
# PRI_lep_phi                      0.002575  0.001273              0.002139
# PRI_met                         -0.087023  0.676428              0.309729
# PRI_met_phi                     -0.002071  0.006874              0.010130
# PRI_met_sumet                    0.057973  0.785054              0.618114
# PRI_jet_num                     -0.022938  0.624089              0.868206
# PRI_jet_leading_pt              -0.015053  0.624620              0.547879
# PRI_jet_leading_eta             -0.009476  0.566766              0.524274
# PRI_jet_leading_phi             -0.009482  0.566756              0.524272
# PRI_jet_subleading_pt           -0.031651  0.531602              0.999323
# PRI_jet_subleading_eta          -0.030899  0.523953              0.999995
# PRI_jet_subleading_phi          -0.030885  0.523981              0.999996
# PRI_jet_all_pt                  -0.049310  0.808764              0.710733
# Label                           -0.015684  0.193857              0.145527
#
#                              DER_mass_jet_jet  DER_prodeta_jet_jet  \
# DER_mass_MMC                         0.160355             0.161689
# DER_mass_transverse_met_lep         -0.192933            -0.179401
# DER_mass_vis                        -0.038740            -0.030808
# DER_pt_h                             0.536391             0.523899
# DER_deltaeta_jet_jet                 0.946692             0.999981
# DER_mass_jet_jet                     1.000000             0.945100
# DER_prodeta_jet_jet                  0.945100             1.000000
# DER_deltar_tau_lep                  -0.307966            -0.301855
# DER_pt_tot                           0.263892             0.285536
# DER_sum_pt                           0.680010             0.669760
# DER_pt_ratio_lep_tau                 0.019598             0.032703
# DER_met_phi_centrality               0.373505             0.373310
# DER_lep_eta_centrality               0.946235             0.999990
# PRI_tau_pt                           0.208211             0.189314
# PRI_tau_eta                          0.007038             0.008682
# PRI_tau_phi                          0.006018             0.004395
# PRI_lep_pt                           0.159993             0.161918
# PRI_lep_eta                          0.011198             0.013314
# PRI_lep_phi                          0.003440             0.002108
# PRI_met                              0.320862             0.309872
# PRI_met_phi                          0.012137             0.010097
# PRI_met_sumet                        0.617483             0.618426
# PRI_jet_num                          0.815693             0.868429
# PRI_jet_leading_pt                   0.524772             0.547876
# PRI_jet_leading_eta                  0.496041             0.524270
# PRI_jet_leading_phi                  0.496043             0.524268
# PRI_jet_subleading_pt                0.948253             0.999325
# PRI_jet_subleading_eta               0.946163             0.999988
# PRI_jet_subleading_phi               0.946158             0.999989
# PRI_jet_all_pt                       0.719133             0.710930
# Label                                0.195348             0.144414
#
#                              DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  \
# DER_mass_MMC                           0.230467    0.048663    0.199939  ...
# DER_mass_transverse_met_lep            0.042715    0.009326   -0.146486  ...
# DER_mass_vis                           0.577503   -0.001245    0.090625  ...
# DER_pt_h                              -0.544633    0.302904    0.833710  ...
# DER_deltaeta_jet_jet                  -0.301857    0.284992    0.669586  ...
# DER_mass_jet_jet                      -0.307966    0.263892    0.680010  ...
# DER_prodeta_jet_jet                   -0.301855    0.285536    0.669760  ...
# DER_deltar_tau_lep                     1.000000   -0.158399   -0.435226  ...
# DER_pt_tot                            -0.158399    1.000000    0.401199  ...
# DER_sum_pt                            -0.435226    0.401199    1.000000  ...
# DER_pt_ratio_lep_tau                   0.052756    0.043296    0.102615  ...
# DER_met_phi_centrality                -0.210216    0.189317    0.420026  ...
# DER_lep_eta_centrality                -0.301892    0.285168    0.669707  ...
# PRI_tau_pt                            -0.207635    0.100800    0.490459  ...
# PRI_tau_eta                            0.002007    0.000487    0.003717  ...
# PRI_tau_phi                           -0.010355   -0.001761    0.005384  ...
# PRI_lep_pt                            -0.069678    0.114564    0.456887  ...
# PRI_lep_eta                            0.003796    0.004937    0.009397  ...
# PRI_lep_phi                           -0.000202   -0.002501    0.001490  ...
# PRI_met                               -0.409826    0.237590    0.526018  ...
# PRI_met_phi                           -0.001369    0.003959    0.007489  ...
# PRI_met_sumet                         -0.408674    0.468740    0.907065  ...
# PRI_jet_num                           -0.350965    0.376895    0.756259  ...
# PRI_jet_leading_pt                    -0.340499    0.211105    0.639221  ...
# PRI_jet_leading_eta                   -0.308317    0.193547    0.578171  ...
# PRI_jet_leading_phi                   -0.308304    0.193570    0.578173  ...
# PRI_jet_subleading_pt                 -0.306085    0.294010    0.685376  ...
# PRI_jet_subleading_eta                -0.301881    0.285198    0.669710  ...
# PRI_jet_subleading_phi                -0.301886    0.285196    0.669721  ...
# PRI_jet_all_pt                        -0.450563    0.424815    0.965813  ...
# Label                                  0.004843   -0.014507    0.153717  ...
#
#                              PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  \
# DER_mass_MMC                      0.219977     0.219547            0.246436
# DER_mass_transverse_met_lep      -0.165226    -0.210067           -0.226202
# DER_mass_vis                      0.057973    -0.022938           -0.015053
# DER_pt_h                          0.785054     0.624089            0.624620
# DER_deltaeta_jet_jet              0.618114     0.868206            0.547879
# DER_mass_jet_jet                  0.617483     0.815693            0.524772
# DER_prodeta_jet_jet               0.618426     0.868429            0.547876
# DER_deltar_tau_lep               -0.408674    -0.350965           -0.340499
# DER_pt_tot                        0.468740     0.376895            0.211105
# DER_sum_pt                        0.907065     0.756259            0.639221
# DER_pt_ratio_lep_tau              0.048374     0.050656            0.049390
# DER_met_phi_centrality            0.422847     0.494714            0.550503
# DER_lep_eta_centrality            0.618274     0.868282            0.547887
# PRI_tau_pt                        0.452726     0.208341            0.203553
# PRI_tau_eta                       0.004323     0.009608            0.009725
# PRI_tau_phi                       0.007425     0.005451            0.006159
# PRI_lep_pt                        0.360079     0.194114            0.187063
# PRI_lep_eta                       0.009136     0.018554            0.021733
# PRI_lep_phi                      -0.003466    -0.000404           -0.002251
# PRI_met                           0.493962     0.342272            0.308624
# PRI_met_phi                       0.005593     0.009381            0.006693
# PRI_met_sumet                     1.000000     0.704133            0.595364
# PRI_jet_num                       0.704133     1.000000            0.833323
# PRI_jet_leading_pt                0.595364     0.833323            1.000000
# PRI_jet_leading_eta               0.540506     0.818059            0.996007
# PRI_jet_leading_phi               0.540518     0.818057            0.996007
# PRI_jet_subleading_pt             0.632448     0.870285            0.548954
# PRI_jet_subleading_eta            0.618283     0.868297            0.547884
# PRI_jet_subleading_phi            0.618301     0.868295            0.547887
# PRI_jet_all_pt                    0.886412     0.801463            0.666006
# Label                             0.138052     0.137610            0.159733
#
#                              PRI_jet_leading_eta  PRI_jet_leading_phi  \
# DER_mass_MMC                            0.243233             0.243216
# DER_mass_transverse_met_lep            -0.216544            -0.216529
# DER_mass_vis                           -0.009476            -0.009482
# DER_pt_h                                0.566766             0.566756
# DER_deltaeta_jet_jet                    0.524274             0.524272
# DER_mass_jet_jet                        0.496041             0.496043
# DER_prodeta_jet_jet                     0.524270             0.524268
# DER_deltar_tau_lep                     -0.308317            -0.308304
# DER_pt_tot                              0.193547             0.193570
# DER_sum_pt                              0.578171             0.578173
# DER_pt_ratio_lep_tau                    0.043828             0.043815
# DER_met_phi_centrality                  0.536328             0.536339
# DER_lep_eta_centrality                  0.524275             0.524273
# PRI_tau_pt                              0.174953             0.174956
# PRI_tau_eta                             0.010343             0.009900
# PRI_tau_phi                             0.005790             0.005382
# PRI_lep_pt                              0.162500             0.162472
# PRI_lep_eta                             0.022630             0.022126
# PRI_lep_phi                            -0.002501            -0.003148
# PRI_met                                 0.260653             0.260651
# PRI_met_phi                             0.006457             0.005799
# PRI_met_sumet                           0.540506             0.540518
# PRI_jet_num                             0.818059             0.818057
# PRI_jet_leading_pt                      0.996007             0.996007
# PRI_jet_leading_eta                     1.000000             0.999992
# PRI_jet_leading_phi                     0.999992             1.000000
# PRI_jet_subleading_pt                   0.523925             0.523923
# PRI_jet_subleading_eta                  0.524272             0.524272
# PRI_jet_subleading_phi                  0.524274             0.524272
# PRI_jet_all_pt                          0.605991             0.605999
# Label                                   0.152657             0.152622
#
#                              PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# DER_mass_MMC                              0.162034                0.161788
# DER_mass_transverse_met_lep              -0.180302               -0.179674
# DER_mass_vis                             -0.031651               -0.030899
# DER_pt_h                                  0.531602                0.523953
# DER_deltaeta_jet_jet                      0.999323                0.999995
# DER_mass_jet_jet                          0.948253                0.946163
# DER_prodeta_jet_jet                       0.999325                0.999988
# DER_deltar_tau_lep                       -0.306085               -0.301881
# DER_pt_tot                                0.294010                0.285198
# DER_sum_pt                                0.685376                0.669710
# DER_pt_ratio_lep_tau                      0.033398                0.032538
# DER_met_phi_centrality                    0.374503                0.373499
# DER_lep_eta_centrality                    0.999332                0.999997
# PRI_tau_pt                                0.193370                0.189428
# PRI_tau_eta                               0.008461                0.008872
# PRI_tau_phi                               0.004494                0.004397
# PRI_lep_pt                                0.165136                0.161822
# PRI_lep_eta                               0.012994                0.013516
# PRI_lep_phi                               0.002090                0.002128
# PRI_met                                   0.316512                0.309809
# PRI_met_phi                               0.010158                0.010132
# PRI_met_sumet                             0.632448                0.618283
# PRI_jet_num                               0.870285                0.868297
# PRI_jet_leading_pt                        0.548954                0.547884
# PRI_jet_leading_eta                       0.523925                0.524272
# PRI_jet_leading_phi                       0.523923                0.524272
# PRI_jet_subleading_pt                     1.000000                0.999329
# PRI_jet_subleading_eta                    0.999329                1.000000
# PRI_jet_subleading_phi                    0.999330                0.999995
# PRI_jet_all_pt                            0.727712                0.710865
# Label                                     0.144352                0.145146
#
#                              PRI_jet_subleading_phi  PRI_jet_all_pt     Label
# DER_mass_MMC                               0.161785        0.183876  0.237261
# DER_mass_transverse_met_lep               -0.179682       -0.209717 -0.351159
# DER_mass_vis                              -0.030885       -0.049310 -0.015684
# DER_pt_h                                   0.523981        0.808764  0.193857
# DER_deltaeta_jet_jet                       0.999996        0.710733  0.145527
# DER_mass_jet_jet                           0.946158        0.719133  0.195348
# DER_prodeta_jet_jet                        0.999989        0.710930  0.144414
# DER_deltar_tau_lep                        -0.301886       -0.450563  0.004843
# DER_pt_tot                                 0.285196        0.424815 -0.014507
# DER_sum_pt                                 0.669721        0.965813  0.153717
# DER_pt_ratio_lep_tau                       0.032541        0.072853 -0.192490
# DER_met_phi_centrality                     0.373499        0.451550  0.269492
# DER_lep_eta_centrality                     0.999998        0.710859  0.145225
# PRI_tau_pt                                 0.189430        0.326401  0.232861
# PRI_tau_eta                                0.008669        0.004212  0.003387
# PRI_tau_phi                                0.004281        0.006252  0.003175
# PRI_lep_pt                                 0.161833        0.291451 -0.028208
# PRI_lep_eta                                0.013304        0.010173  0.005663
# PRI_lep_phi                                0.001967        0.000059  0.007352
# PRI_met                                    0.309830        0.539582  0.019766
# PRI_met_phi                                0.009978        0.007779  0.009986
# PRI_met_sumet                              0.618301        0.886412  0.138052
# PRI_jet_num                                0.868295        0.801463  0.137610
# PRI_jet_leading_pt                         0.547887        0.666006  0.159733
# PRI_jet_leading_eta                        0.524274        0.605991  0.152657
# PRI_jet_leading_phi                        0.524272        0.605999  0.152622
# PRI_jet_subleading_pt                      0.999330        0.727712  0.144352
# PRI_jet_subleading_eta                     0.999995        0.710865  0.145146
# PRI_jet_subleading_phi                     1.000000        0.710876  0.145134
# PRI_jet_all_pt                             0.710876        1.000000  0.134440
# Label                                      0.145134        0.134440  1.000000
#
# [31 rows x 31 columns]

# %%
l = []
dif =1.0, 'Label'
for feature in zip(corr_matrix['Label'],df.columns):
    if(dif != feature):
        l.append(feature)
l.sort(reverse=True)
l
# Out:
# [(0.2694915515988635, 'DER_met_phi_centrality'),
#  (0.23726092955589645, 'DER_mass_MMC'),
#  (0.2328606082210151, 'PRI_tau_pt'),
#  (0.19534804186060856, 'DER_mass_jet_jet'),
#  (0.1938569228983593, 'DER_pt_h'),
#  (0.15973339664168917, 'PRI_jet_leading_pt'),
#  (0.15371678637044095, 'DER_sum_pt'),
#  (0.1526567561750736, 'PRI_jet_leading_eta'),
#  (0.1526224862108924, 'PRI_jet_leading_phi'),
#  (0.1455272541074062, 'DER_deltaeta_jet_jet'),
#  (0.1452253455091279, 'DER_lep_eta_centrality'),
#  (0.14514590541580288, 'PRI_jet_subleading_eta'),
#  (0.14513405448811736, 'PRI_jet_subleading_phi'),
#  (0.14441387982683138, 'DER_prodeta_jet_jet'),
#  (0.14435245536997215, 'PRI_jet_subleading_pt'),
#  (0.1380524900265753, 'PRI_met_sumet'),
#  (0.13761023264857042, 'PRI_jet_num'),
#  (0.1344397314285392, 'PRI_jet_all_pt'),
#  (0.019766102889927587, 'PRI_met'),
#  (0.009986236015714885, 'PRI_met_phi'),
#  (0.007351594846955683, 'PRI_lep_phi'),
#  (0.0056633416065110485, 'PRI_lep_eta'),
#  (0.0048428896623217465, 'DER_deltar_tau_lep'),
#  (0.003387366153866935, 'PRI_tau_eta'),
#  (0.0031752921434645633, 'PRI_tau_phi'),
#  (-0.014506566909448196, 'DER_pt_tot'),
#  (-0.015683783800948547, 'DER_mass_vis'),
#  (-0.02820808873626438, 'PRI_lep_pt'),
#  (-0.19249038723783662, 'DER_pt_ratio_lep_tau'),
#  (-0.35115930828435454, 'DER_mass_transverse_met_lep')]

# %%
l_i = []
l_v = []
for importance in range(len(l)):
    for var in range(len(l[importance])):
        if(var == 0):
            l_i.append(l[importance][var])
        else:
            l_v.append(l[importance][var])

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array(l_i[0:10])
x = np.array(l_v[0:10])

# %%
import matplotlib
font = {'size'   : 16}
matplotlib.rc('font', **font)
fig = plt.figure(figsize = (20, 10))


# creating the bar plot
plt.ylabel("Importancia")
plt.bar(x, y, color ='red',
        width = 0.9)
plt.xticks(rotation=45, ha='right')
plt.title("Ranking Top 10 de variables usando Correlación de Pearson")
plt.show()
