# %%
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/Users/Alex/Downloads/Pre-procesado.csv")

# %%
X_train = df  #Feature Matrix

y_train = df["Label"]

# %%
corr_matrix = X_train.corr(method="pearson")
plt.figure(figsize=(12, 10))
heatmap = sns.heatmap(corr_matrix, vmin=-1, vmax=1, cmap='BrBG', annot = True, fmt=".2f", annot_kws={"size":7})
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':8}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
corr_matrix
# Out:
#                              DER_mass_MMC  DER_mass_transverse_met_lep  \
# DER_mass_MMC                     1.000000                    -0.454565
# DER_mass_transverse_met_lep     -0.454565                     1.000000
# DER_mass_vis                     0.172250                     0.187320
# DER_pt_h                         0.197366                    -0.253299
# DER_deltaeta_jet_jet             0.161830                    -0.179828
# DER_mass_jet_jet                 0.160355                    -0.192933
# DER_prodeta_jet_jet              0.161689                    -0.179401
# DER_deltar_tau_lep               0.230467                     0.042715
# DER_pt_tot                       0.048663                     0.009326
# DER_sum_pt                       0.199939                    -0.146486
# DER_pt_ratio_lep_tau            -0.014223                     0.340963
# DER_met_phi_centrality           0.358729                    -0.418197
# DER_lep_eta_centrality           0.161790                    -0.179705
# PRI_tau_pt                       0.127415                    -0.136176
# PRI_tau_eta                      0.004587                    -0.005670
# PRI_tau_phi                     -0.006143                     0.000150
# PRI_lep_pt                       0.102582                     0.304080
# PRI_lep_eta                      0.007381                    -0.006909
# PRI_lep_phi                     -0.004642                     0.002538
# PRI_met                         -0.237121                     0.183764
# PRI_met_phi                      0.007564                    -0.018560
# PRI_met_sumet                    0.219977                    -0.165226
# PRI_jet_num                      0.219547                    -0.210067
# PRI_jet_leading_pt               0.246436                    -0.226202
# PRI_jet_leading_eta              0.243233                    -0.216544
# PRI_jet_leading_phi              0.243216                    -0.216529
# PRI_jet_subleading_pt            0.162034                    -0.180302
# PRI_jet_subleading_eta           0.161788                    -0.179674
# PRI_jet_subleading_phi           0.161785                    -0.179682
# PRI_jet_all_pt                   0.183876                    -0.209717
# Weight                          -0.325253                     0.416957
# Label                            0.237261                    -0.351159
# KaggleWeight                    -0.134890                     0.174225
#
#                              DER_mass_vis  DER_pt_h  DER_deltaeta_jet_jet  \
# DER_mass_MMC                     0.172250  0.197366              0.161830
# DER_mass_transverse_met_lep      0.187320 -0.253299             -0.179828
# DER_mass_vis                     1.000000 -0.061082             -0.030928
# DER_pt_h                        -0.061082  1.000000              0.523925
# DER_deltaeta_jet_jet            -0.030928  0.523925              1.000000
# DER_mass_jet_jet                -0.038740  0.536391              0.946692
# DER_prodeta_jet_jet             -0.030808  0.523899              0.999981
# DER_deltar_tau_lep               0.577503 -0.544633             -0.301857
# DER_pt_tot                      -0.001245  0.302904              0.284992
# DER_sum_pt                       0.090625  0.833710              0.669586
# DER_pt_ratio_lep_tau             0.100225  0.087215              0.032426
# DER_met_phi_centrality          -0.093310  0.540353              0.373591
# DER_lep_eta_centrality          -0.030901  0.523979              0.999998
# PRI_tau_pt                       0.286945  0.410942              0.189456
# PRI_tau_eta                     -0.001179  0.005686              0.008666
# PRI_tau_phi                     -0.005519  0.005706              0.004398
# PRI_lep_pt                       0.405197  0.362919              0.161729
# PRI_lep_eta                      0.009118  0.012058              0.013308
# PRI_lep_phi                      0.002575  0.001273              0.002139
# PRI_met                         -0.087023  0.676428              0.309729
# PRI_met_phi                     -0.002071  0.006874              0.010130
# PRI_met_sumet                    0.057973  0.785054              0.618114
# PRI_jet_num                     -0.022938  0.624089              0.868206
# PRI_jet_leading_pt              -0.015053  0.624620              0.547879
# PRI_jet_leading_eta             -0.009476  0.566766              0.524274
# PRI_jet_leading_phi             -0.009482  0.566756              0.524272
# PRI_jet_subleading_pt           -0.031651  0.531602              0.999323
# PRI_jet_subleading_eta          -0.030899  0.523953              0.999995
# PRI_jet_subleading_phi          -0.030885  0.523981              0.999996
# PRI_jet_all_pt                  -0.049310  0.808764              0.710733
# Weight                           0.102796 -0.416391             -0.399939
# Label                           -0.015684  0.193857              0.145527
# KaggleWeight                     0.044096 -0.174290             -0.166575
#
#                              DER_mass_jet_jet  DER_prodeta_jet_jet  \
# DER_mass_MMC                         0.160355             0.161689
# DER_mass_transverse_met_lep         -0.192933            -0.179401
# DER_mass_vis                        -0.038740            -0.030808
# DER_pt_h                             0.536391             0.523899
# DER_deltaeta_jet_jet                 0.946692             0.999981
# DER_mass_jet_jet                     1.000000             0.945100
# DER_prodeta_jet_jet                  0.945100             1.000000
# DER_deltar_tau_lep                  -0.307966            -0.301855
# DER_pt_tot                           0.263892             0.285536
# DER_sum_pt                           0.680010             0.669760
# DER_pt_ratio_lep_tau                 0.019598             0.032703
# DER_met_phi_centrality               0.373505             0.373310
# DER_lep_eta_centrality               0.946235             0.999990
# PRI_tau_pt                           0.208211             0.189314
# PRI_tau_eta                          0.007038             0.008682
# PRI_tau_phi                          0.006018             0.004395
# PRI_lep_pt                           0.159993             0.161918
# PRI_lep_eta                          0.011198             0.013314
# PRI_lep_phi                          0.003440             0.002108
# PRI_met                              0.320862             0.309872
# PRI_met_phi                          0.012137             0.010097
# PRI_met_sumet                        0.617483             0.618426
# PRI_jet_num                          0.815693             0.868429
# PRI_jet_leading_pt                   0.524772             0.547876
# PRI_jet_leading_eta                  0.496041             0.524270
# PRI_jet_leading_phi                  0.496043             0.524268
# PRI_jet_subleading_pt                0.948253             0.999325
# PRI_jet_subleading_eta               0.946163             0.999988
# PRI_jet_subleading_phi               0.946158             0.999989
# PRI_jet_all_pt                       0.719133             0.710930
# Weight                              -0.398306            -0.399569
# Label                                0.195348             0.144414
# KaggleWeight                        -0.166562            -0.166410
#
#                              DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  \
# DER_mass_MMC                           0.230467    0.048663    0.199939  ...
# DER_mass_transverse_met_lep            0.042715    0.009326   -0.146486  ...
# DER_mass_vis                           0.577503   -0.001245    0.090625  ...
# DER_pt_h                              -0.544633    0.302904    0.833710  ...
# DER_deltaeta_jet_jet                  -0.301857    0.284992    0.669586  ...
# DER_mass_jet_jet                      -0.307966    0.263892    0.680010  ...
# DER_prodeta_jet_jet                   -0.301855    0.285536    0.669760  ...
# DER_deltar_tau_lep                     1.000000   -0.158399   -0.435226  ...
# DER_pt_tot                            -0.158399    1.000000    0.401199  ...
# DER_sum_pt                            -0.435226    0.401199    1.000000  ...
# DER_pt_ratio_lep_tau                   0.052756    0.043296    0.102615  ...
# DER_met_phi_centrality                -0.210216    0.189317    0.420026  ...
# DER_lep_eta_centrality                -0.301892    0.285168    0.669707  ...
# PRI_tau_pt                            -0.207635    0.100800    0.490459  ...
# PRI_tau_eta                            0.002007    0.000487    0.003717  ...
# PRI_tau_phi                           -0.010355   -0.001761    0.005384  ...
# PRI_lep_pt                            -0.069678    0.114564    0.456887  ...
# PRI_lep_eta                            0.003796    0.004937    0.009397  ...
# PRI_lep_phi                           -0.000202   -0.002501    0.001490  ...
# PRI_met                               -0.409826    0.237590    0.526018  ...
# PRI_met_phi                           -0.001369    0.003959    0.007489  ...
# PRI_met_sumet                         -0.408674    0.468740    0.907065  ...
# PRI_jet_num                           -0.350965    0.376895    0.756259  ...
# PRI_jet_leading_pt                    -0.340499    0.211105    0.639221  ...
# PRI_jet_leading_eta                   -0.308317    0.193547    0.578171  ...
# PRI_jet_leading_phi                   -0.308304    0.193570    0.578173  ...
# PRI_jet_subleading_pt                 -0.306085    0.294010    0.685376  ...
# PRI_jet_subleading_eta                -0.301881    0.285198    0.669710  ...
# PRI_jet_subleading_phi                -0.301886    0.285196    0.669721  ...
# PRI_jet_all_pt                        -0.450563    0.424815    0.965813  ...
# Weight                                 0.204694   -0.228744   -0.414838  ...
# Label                                  0.004843   -0.014507    0.153717  ...
# KaggleWeight                           0.086918   -0.095417   -0.174495  ...
#
#                              PRI_jet_leading_pt  PRI_jet_leading_eta  \
# DER_mass_MMC                           0.246436             0.243233
# DER_mass_transverse_met_lep           -0.226202            -0.216544
# DER_mass_vis                          -0.015053            -0.009476
# DER_pt_h                               0.624620             0.566766
# DER_deltaeta_jet_jet                   0.547879             0.524274
# DER_mass_jet_jet                       0.524772             0.496041
# DER_prodeta_jet_jet                    0.547876             0.524270
# DER_deltar_tau_lep                    -0.340499            -0.308317
# DER_pt_tot                             0.211105             0.193547
# DER_sum_pt                             0.639221             0.578171
# DER_pt_ratio_lep_tau                   0.049390             0.043828
# DER_met_phi_centrality                 0.550503             0.536328
# DER_lep_eta_centrality                 0.547887             0.524275
# PRI_tau_pt                             0.203553             0.174953
# PRI_tau_eta                            0.009725             0.010343
# PRI_tau_phi                            0.006159             0.005790
# PRI_lep_pt                             0.187063             0.162500
# PRI_lep_eta                            0.021733             0.022630
# PRI_lep_phi                           -0.002251            -0.002501
# PRI_met                                0.308624             0.260653
# PRI_met_phi                            0.006693             0.006457
# PRI_met_sumet                          0.595364             0.540506
# PRI_jet_num                            0.833323             0.818059
# PRI_jet_leading_pt                     1.000000             0.996007
# PRI_jet_leading_eta                    0.996007             1.000000
# PRI_jet_leading_phi                    0.996007             0.999992
# PRI_jet_subleading_pt                  0.548954             0.523925
# PRI_jet_subleading_eta                 0.547884             0.524272
# PRI_jet_subleading_phi                 0.547887             0.524274
# PRI_jet_all_pt                         0.666006             0.605991
# Weight                                -0.514353            -0.505256
# Label                                  0.159733             0.152657
# KaggleWeight                          -0.213592            -0.209593
#
#                              PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# DER_mass_MMC                            0.243216               0.162034
# DER_mass_transverse_met_lep            -0.216529              -0.180302
# DER_mass_vis                           -0.009482              -0.031651
# DER_pt_h                                0.566756               0.531602
# DER_deltaeta_jet_jet                    0.524272               0.999323
# DER_mass_jet_jet                        0.496043               0.948253
# DER_prodeta_jet_jet                     0.524268               0.999325
# DER_deltar_tau_lep                     -0.308304              -0.306085
# DER_pt_tot                              0.193570               0.294010
# DER_sum_pt                              0.578173               0.685376
# DER_pt_ratio_lep_tau                    0.043815               0.033398
# DER_met_phi_centrality                  0.536339               0.374503
# DER_lep_eta_centrality                  0.524273               0.999332
# PRI_tau_pt                              0.174956               0.193370
# PRI_tau_eta                             0.009900               0.008461
# PRI_tau_phi                             0.005382               0.004494
# PRI_lep_pt                              0.162472               0.165136
# PRI_lep_eta                             0.022126               0.012994
# PRI_lep_phi                            -0.003148               0.002090
# PRI_met                                 0.260651               0.316512
# PRI_met_phi                             0.005799               0.010158
# PRI_met_sumet                           0.540518               0.632448
# PRI_jet_num                             0.818057               0.870285
# PRI_jet_leading_pt                      0.996007               0.548954
# PRI_jet_leading_eta                     0.999992               0.523925
# PRI_jet_leading_phi                     1.000000               0.523923
# PRI_jet_subleading_pt                   0.523923               1.000000
# PRI_jet_subleading_eta                  0.524272               0.999329
# PRI_jet_subleading_phi                  0.524272               0.999330
# PRI_jet_all_pt                          0.605999               0.727712
# Weight                                 -0.505241              -0.400381
# Label                                   0.152622               0.144352
# KaggleWeight                           -0.209594              -0.166788
#
#                              PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# DER_mass_MMC                               0.161788                0.161785
# DER_mass_transverse_met_lep               -0.179674               -0.179682
# DER_mass_vis                              -0.030899               -0.030885
# DER_pt_h                                   0.523953                0.523981
# DER_deltaeta_jet_jet                       0.999995                0.999996
# DER_mass_jet_jet                           0.946163                0.946158
# DER_prodeta_jet_jet                        0.999988                0.999989
# DER_deltar_tau_lep                        -0.301881               -0.301886
# DER_pt_tot                                 0.285198                0.285196
# DER_sum_pt                                 0.669710                0.669721
# DER_pt_ratio_lep_tau                       0.032538                0.032541
# DER_met_phi_centrality                     0.373499                0.373499
# DER_lep_eta_centrality                     0.999997                0.999998
# PRI_tau_pt                                 0.189428                0.189430
# PRI_tau_eta                                0.008872                0.008669
# PRI_tau_phi                                0.004397                0.004281
# PRI_lep_pt                                 0.161822                0.161833
# PRI_lep_eta                                0.013516                0.013304
# PRI_lep_phi                                0.002128                0.001967
# PRI_met                                    0.309809                0.309830
# PRI_met_phi                                0.010132                0.009978
# PRI_met_sumet                              0.618283                0.618301
# PRI_jet_num                                0.868297                0.868295
# PRI_jet_leading_pt                         0.547884                0.547887
# PRI_jet_leading_eta                        0.524272                0.524274
# PRI_jet_leading_phi                        0.524272                0.524272
# PRI_jet_subleading_pt                      0.999329                0.999330
# PRI_jet_subleading_eta                     1.000000                0.999995
# PRI_jet_subleading_phi                     0.999995                1.000000
# PRI_jet_all_pt                             0.710865                0.710876
# Weight                                    -0.399812               -0.399807
# Label                                      0.145146                0.145134
# KaggleWeight                              -0.166515               -0.166512
#
#                              PRI_jet_all_pt    Weight     Label  KaggleWeight
# DER_mass_MMC                       0.183876 -0.325253  0.237261     -0.134890
# DER_mass_transverse_met_lep       -0.209717  0.416957 -0.351159      0.174225
# DER_mass_vis                      -0.049310  0.102796 -0.015684      0.044096
# DER_pt_h                           0.808764 -0.416391  0.193857     -0.174290
# DER_deltaeta_jet_jet               0.710733 -0.399939  0.145527     -0.166575
# DER_mass_jet_jet                   0.719133 -0.398306  0.195348     -0.166562
# DER_prodeta_jet_jet                0.710930 -0.399569  0.144414     -0.166410
# DER_deltar_tau_lep                -0.450563  0.204694  0.004843      0.086918
# DER_pt_tot                         0.424815 -0.228744 -0.014507     -0.095417
# DER_sum_pt                         0.965813 -0.414838  0.153717     -0.174495
# DER_pt_ratio_lep_tau               0.072853  0.186887 -0.192490      0.074610
# DER_met_phi_centrality             0.451550 -0.472327  0.269492     -0.199528
# DER_lep_eta_centrality             0.710859 -0.399835  0.145225     -0.166527
# PRI_tau_pt                         0.326401 -0.281570  0.232861     -0.118499
# PRI_tau_eta                        0.004212 -0.010129  0.003387      0.001753
# PRI_tau_phi                        0.006252 -0.002020  0.003175      0.003496
# PRI_lep_pt                         0.291451 -0.023406 -0.028208     -0.012887
# PRI_lep_eta                        0.010173 -0.022656  0.005663     -0.004019
# PRI_lep_phi                        0.000059 -0.000912  0.007352      0.002266
# PRI_met                            0.539582 -0.120474  0.019766     -0.051024
# PRI_met_phi                        0.007779 -0.011378  0.009986     -0.009141
# PRI_met_sumet                      0.886412 -0.427345  0.138052     -0.179345
# PRI_jet_num                        0.801463 -0.497889  0.137610     -0.206835
# PRI_jet_leading_pt                 0.666006 -0.514353  0.159733     -0.213592
# PRI_jet_leading_eta                0.605991 -0.505256  0.152657     -0.209593
# PRI_jet_leading_phi                0.605999 -0.505241  0.152622     -0.209594
# PRI_jet_subleading_pt              0.727712 -0.400381  0.144352     -0.166788
# PRI_jet_subleading_eta             0.710865 -0.399812  0.145146     -0.166515
# PRI_jet_subleading_phi             0.710876 -0.399807  0.145134     -0.166512
# PRI_jet_all_pt                     1.000000 -0.419930  0.134440     -0.175943
# Weight                            -0.419930  1.000000 -0.628908      0.422484
# Label                              0.134440 -0.628908  1.000000     -0.266373
# KaggleWeight                      -0.175943  0.422484 -0.266373      1.000000
#
# [33 rows x 33 columns]

# %%
X_train.columns
# Out:
# Index(['DER_mass_MMC', 'DER_mass_transverse_met_lep', 'DER_mass_vis',
#        'DER_pt_h', 'DER_deltaeta_jet_jet', 'DER_mass_jet_jet',
#        'DER_prodeta_jet_jet', 'DER_deltar_tau_lep', 'DER_pt_tot', 'DER_sum_pt',
#        'DER_pt_ratio_lep_tau', 'DER_met_phi_centrality',
#        'DER_lep_eta_centrality', 'PRI_tau_pt', 'PRI_tau_eta', 'PRI_tau_phi',
#        'PRI_lep_pt', 'PRI_lep_eta', 'PRI_lep_phi', 'PRI_met', 'PRI_met_phi',
#        'PRI_met_sumet', 'PRI_jet_num', 'PRI_jet_leading_pt',
#        'PRI_jet_leading_eta', 'PRI_jet_leading_phi', 'PRI_jet_subleading_pt',
#        'PRI_jet_subleading_eta', 'PRI_jet_subleading_phi', 'PRI_jet_all_pt',
#        'Weight', 'Label', 'KaggleWeight'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
x = corr_matrix['Label']
y = X_train.columns

# %%
plt.ylabel("Label")
ax = plt.gca()
x.sort_values(ascending=False).plot(kind='bar',x=y,y='Label',ax=ax)
plt.show()
