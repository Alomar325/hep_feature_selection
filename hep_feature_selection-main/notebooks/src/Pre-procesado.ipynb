# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/Alex/Downloads/higgs_reducido.csv")

# %%
df.head()
# Out:
#     index  EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0  138682   238682        85.123                        5.111        45.454
# 1  271291   371291        70.751                       16.532        47.178
# 2  489566   589566      -999.000                       79.211        77.286
# 3  377268   477268        74.959                       58.796        58.484
# 4  323429   423429      -999.000                       82.701       109.640
#
#    DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0   139.856              -999.000          -999.000             -999.000
# 1   107.916                 4.446           442.881               -4.514
# 2     0.998              -999.000          -999.000             -999.000
# 3    24.962              -999.000          -999.000             -999.000
# 4     2.044              -999.000          -999.000             -999.000
#
#    DER_deltar_tau_lep  ...  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0               1.288  ...               -0.903                0.656
# 1               1.221  ...               -2.876                2.317
# 2               1.879  ...             -999.000             -999.000
# 3               2.628  ...             -999.000             -999.000
# 4               2.674  ...             -999.000             -999.000
#
#    PRI_jet_subleading_pt  PRI_jet_subleading_eta  PRI_jet_subleading_phi  \
# 0               -999.000                 -999.00                -999.000
# 1                 39.964                    1.57                   1.271
# 2               -999.000                 -999.00                -999.000
# 3               -999.000                 -999.00                -999.000
# 4               -999.000                 -999.00                -999.000
#
#    PRI_jet_all_pt    Weight  Label  KaggleSet  KaggleWeight
# 0         145.787  0.512740      b          t      1.681611
# 1         137.049  0.019533      b          v      0.035515
# 2           0.000  0.000814      s          v      0.001483
# 3           0.000  0.094460      b          v      0.171749
# 4           0.000  0.795081      b          v      1.445639
#
# [5 rows x 36 columns]

# %%
df['Label']
# Out:
# 0        b
# 1        b
# 2        s
# 3        b
# 4        b
#         ..
# 99995    b
# 99996    b
# 99997    s
# 99998    b
# 99999    b
# Name: Label, Length: 100000, dtype: object

# %%
contS = 0
contB = 0
for i in df['Label']:
    if (i == 's'):
        contS = contS + 1
    else:
        contB = contB + 1
        
print("contS: ",contS)
print("contB:",contB)
# Out:
# contS:  34000
# contB: 66000

# %%
df2 = df.replace('s', 1)
df2.head()
df3 = df2.replace('b', 0)

# %%
df3['Label']
# Out:
# 0        0
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 99995    0
# 99996    0
# 99997    1
# 99998    0
# 99999    0
# Name: Label, Length: 100000, dtype: int64

# %%
invalidos = 0
valores=0
for i in df['DER_mass_jet_jet']: #dentro del df se cambia las variables para hacer el promedio
    if(i>=-998.000):
        valores = i + valores
promedio = valores/818238
print(promedio)
df3.loc[df3.DER_mass_jet_jet<(-998.000),'DER_mass_jet_jet']=promedio
df3.head()
# Out:
# 108.24907562836133
#    EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0   100000    138.470000                       51.655        97.827    27.980
# 1   100001    160.937000                       68.768       103.235    48.146
# 2   100002    103.309577                      162.172       125.953    35.635
# 3   100003    143.905000                       81.417        80.943     0.414
# 4   100004    175.864000                       16.915       134.805    16.405
#
#    DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0              0.910000        124.711000                2.666
# 1              0.699387        108.249076             -999.000
# 2              0.699387        108.249076             -999.000
# 3              0.699387        108.249076             -999.000
# 4              0.699387        108.249076             -999.000
#
#    DER_deltar_tau_lep  DER_pt_tot  ...  PRI_jet_leading_eta  \
# 0               3.064      41.928  ...                2.150
# 1               3.473       2.078  ...                0.725
# 2               3.148       9.336  ...                2.053
# 3               3.310       0.414  ...             -999.000
# 4               3.891      16.405  ...             -999.000
#
#    PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# 0                0.444                 46.062                    1.24
# 1                1.158               -999.000                 -999.00
# 2               -2.028               -999.000                 -999.00
# 3             -999.000               -999.000                 -999.00
# 4             -999.000               -999.000                 -999.00
#
#    PRI_jet_subleading_phi  PRI_jet_all_pt    Weight  Label  KaggleSet  \
# 0               -2.475000         113.497  0.000814      1          t
# 1               -0.003045          46.226  0.681042      0          t
# 2               -0.003045          44.251  0.715742      0          t
# 3               -0.003045          -0.000  1.660654      0          t
# 4               -0.003045           0.000  1.904263      0          t
#
#    KaggleWeight
# 0      0.002653
# 1      2.233584
# 2      2.347389
# 3      5.446378
# 4      6.245333
#
# [5 rows x 35 columns]

# %%
df3 = df3.drop(labels=['KaggleSet','EventId','index'], axis=1)
print(df3)
# Out:
#        DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0            85.123                        5.111        45.454   139.856
# 1            70.751                       16.532        47.178   107.916
# 2          -999.000                       79.211        77.286     0.998
# 3            74.959                       58.796        58.484    24.962
# 4          -999.000                       82.701       109.640     2.044
# ...             ...                          ...           ...       ...
# 99995        95.075                        9.736        62.654   165.282
# 99996       108.208                       20.509        70.580    56.085
# 99997        77.503                       20.791        44.842    99.933
# 99998        96.531                       12.773        60.703   187.917
# 99999      -999.000                       51.909       143.266    30.074
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                  -999.000          -999.000             -999.000
# 1                     4.446           442.881               -4.514
# 2                  -999.000          -999.000             -999.000
# 3                  -999.000          -999.000             -999.000
# 4                  -999.000          -999.000             -999.000
# ...                     ...               ...                  ...
# 99995              -999.000          -999.000             -999.000
# 99996                 2.810           246.437               -0.842
# 99997              -999.000          -999.000             -999.000
# 99998                 1.139           169.441                0.059
# 99999              -999.000          -999.000             -999.000
#
#        DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  ...  PRI_jet_leading_pt  \
# 0                   1.288       6.593     212.788  ...             145.787
# 1                   1.221      49.749     209.956  ...              58.119
# 2                   1.879       0.998      92.329  ...            -999.000
# 3                   2.628      24.962      57.390  ...            -999.000
# 4                   2.674       2.044      62.347  ...            -999.000
# ...                   ...         ...         ...  ...                 ...
# 99995               1.078      24.675     271.045  ...             154.838
# 99996               2.551       4.378     176.428  ...              62.533
# 99997               1.628       2.970     156.158  ...              97.379
# 99998               1.031      71.559     393.666  ...             126.766
# 99999               2.847      30.074     162.494  ...            -999.000
#
#        PRI_jet_leading_eta  PRI_jet_leading_phi  PRI_jet_subleading_pt  \
# 0                   -0.903                0.656               -999.000
# 1                   -2.876                2.317                 39.964
# 2                 -999.000             -999.000               -999.000
# 3                 -999.000             -999.000               -999.000
# 4                 -999.000             -999.000               -999.000
# ...                    ...                  ...                    ...
# 99995               -0.962                1.169               -999.000
# 99996               -0.341                0.196                 54.623
# 99997               -2.383                3.053               -999.000
# 99998                1.188                2.368                 54.060
# 99999             -999.000             -999.000               -999.000
#
#        PRI_jet_subleading_eta  PRI_jet_subleading_phi  PRI_jet_all_pt  \
# 0                    -999.000                -999.000         145.787
# 1                       1.570                   1.271         137.049
# 2                    -999.000                -999.000           0.000
# 3                    -999.000                -999.000           0.000
# 4                    -999.000                -999.000           0.000
# ...                       ...                     ...             ...
# 99995                -999.000                -999.000         154.838
# 99996                   2.469                   2.265         117.155
# 99997                -999.000                -999.000          97.379
# 99998                   0.049                   0.449         270.979
# 99999                -999.000                -999.000           0.000
#
#          Weight  Label  KaggleWeight
# 0      0.512740      0      1.681611
# 1      0.019533      0      0.035515
# 2      0.000814      1      0.001483
# 3      0.094460      0      0.171749
# 4      0.795081      0      1.445639
# ...         ...    ...           ...
# 99995  0.093659      0      0.307170
# 99996  0.022533      0      0.183515
# 99997  0.000461      1      0.003789
# 99998  0.019533      0      0.159083
# 99999  0.528478      0      0.960893
#
# [100000 rows x 33 columns]

# %%
df3.to_csv('/Users/Alex/Downloads/Pre-procesado.csv', index=False)

# %%
df3.iloc[:,[-3,1,2,3,4,5,6]]
# Out:
#          Weight  DER_mass_transverse_met_lep  DER_mass_vis  DER_pt_h  \
# 0      0.512740                        5.111        45.454   139.856
# 1      0.019533                       16.532        47.178   107.916
# 2      0.000814                       79.211        77.286     0.998
# 3      0.094460                       58.796        58.484    24.962
# 4      0.795081                       82.701       109.640     2.044
# ...         ...                          ...           ...       ...
# 99995  0.093659                        9.736        62.654   165.282
# 99996  0.022533                       20.509        70.580    56.085
# 99997  0.000461                       20.791        44.842    99.933
# 99998  0.019533                       12.773        60.703   187.917
# 99999  0.528478                       51.909       143.266    30.074
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet
# 0                  -999.000          -999.000             -999.000
# 1                     4.446           442.881               -4.514
# 2                  -999.000          -999.000             -999.000
# 3                  -999.000          -999.000             -999.000
# 4                  -999.000          -999.000             -999.000
# ...                     ...               ...                  ...
# 99995              -999.000          -999.000             -999.000
# 99996                 2.810           246.437               -0.842
# 99997              -999.000          -999.000             -999.000
# 99998                 1.139           169.441                0.059
# 99999              -999.000          -999.000             -999.000
#
# [100000 rows x 7 columns]

# %%
df.iloc[:,[-3,1,2,3,4,5,6]]
# Out:
#       Label  EventId  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# 0         b   238682        85.123                        5.111        45.454
# 1         b   371291        70.751                       16.532        47.178
# 2         s   589566      -999.000                       79.211        77.286
# 3         b   477268        74.959                       58.796        58.484
# 4         b   423429      -999.000                       82.701       109.640
# ...     ...      ...           ...                          ...           ...
# 99995     b   276894        95.075                        9.736        62.654
# 99996     b   672671       108.208                       20.509        70.580
# 99997     s   509655        77.503                       20.791        44.842
# 99998     b   379185        96.531                       12.773        60.703
# 99999     b   529106      -999.000                       51.909       143.266
#
#        DER_pt_h  DER_deltaeta_jet_jet
# 0       139.856              -999.000
# 1       107.916                 4.446
# 2         0.998              -999.000
# 3        24.962              -999.000
# 4         2.044              -999.000
# ...         ...                   ...
# 99995   165.282              -999.000
# 99996    56.085                 2.810
# 99997    99.933              -999.000
# 99998   187.917                 1.139
# 99999    30.074              -999.000
#
# [100000 rows x 7 columns]
